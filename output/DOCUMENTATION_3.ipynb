// %% [markdown]
// # Numerical widgets

// %% [markdown]
// ## Defining a Slider Widget

// %%
#include <iostream>

// %%
std::cout << "hello";
// Out:
// hello

// %%
!ls
// Out:
// Big.Buck.Bunny.mp3
// Big.Buck.Bunny.mp4
// marie.png
// xwidgets.ipynb
